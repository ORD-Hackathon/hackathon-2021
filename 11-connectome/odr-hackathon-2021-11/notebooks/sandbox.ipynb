# %% [markdown]
# # Add Google Scholar IDs to SNF researchers records in SNFp3
#
# This notebook is a sandbox to test approaches and propose solutions.
#
# ## Setup

# %%
import os
import glob
import pandas as pd
import pickle
import re
from scholarly import scholarly

datadir = os.path.join(os.getcwd(), "..", "data")

# Load SNF data tables
snfdir = glob.glob(os.path.join(datadir, "snf/*.csv"))
snf = {}
# Uncomment to load all the SNF data tables
"""
for fp in snfdir:
    print(os.path.basename(fp))
    snf[os.path.basename(fp)] = pd.read_csv(fp, sep = ";")
"""
# Load the SNF authors table
fp = os.path.join(datadir, 'snf', 'P3_PersonExport.csv')
print(os.path.basename(fp))
snf[os.path.basename(fp)] = pd.read_csv(fp, sep = ";")
# Out:
# P3_PersonExport.csv

# %%
# Have a look at the authors record
snf["P3_PersonExport.csv"].head()
# Out:
#    Last Name First Name  Gender      Institute Name Institute Place  \
# 0    a Marca     Davide    male                 NaN             NaN
# 1    a Marca     Andrea    male                 NaN             NaN
# 2  A. Jafari     Golnaz  female  Universität Luzern          Luzern
# 3     Aaberg      Johan    male                 NaN             NaN
# 4     Aahman    Josefin  female                 NaN             NaN
#
#    Person ID SNSF OCRID Projects as responsible Applicant  \
# 0           53856   NaN                               NaN
# 1          132628   NaN                             67368
# 2          747886   NaN                            191432
# 3          575257   NaN                               NaN
# 4          629557   NaN                               NaN
#
#   Projects as Applicant Projects as Partner Projects as Practice Partner  \
# 0                   NaN                 NaN                          NaN
# 1                   NaN                 NaN                          NaN
# 2                   NaN                 NaN                          NaN
# 3                   NaN                 NaN                          NaN
# 4                   NaN                 NaN                          NaN
#
#   Projects as Employee Projects as Contact Person
# 0                36549                        NaN
# 1                  NaN                        NaN
# 2                  NaN                        NaN
# 3               119868                        NaN
# 4               141014                        NaN

# %% [markdown]
# ## Extract authors Google Scholar IDs and add them to the SNF authors record
#
# WARNING: Google Scholar limits the number of requests! Test can be done on a small number of records only. A solution should be found if more requests are needed.

# %%
# Test the Scholarly API search by author name

search_query = scholarly.search_author('Alexis Rapin')
author = next(search_query)

# %%
author
# Out:
# {'container_type': 'Author',
#  'filled': set(),
#  'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 2>,
#  'scholar_id': 'ZgCd-OgAAAAJ',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=ZgCd-OgAAAAJ',
#  'name': 'Alexis Rapin',
#  'affiliation': 'EPFL',
#  'email_domain': '@epfl.ch',
#  'interests': ['bioinformatics', 'open science', 'data science'],
#  'citedby': 328}

# %%
# Add retrieved Google Scholar ID(s) to the SNF authors record when available
# Use a subset of the records ony (35) to avoid robot-behavior falgging

snf_person_head = snf["P3_PersonExport.csv"].head(35)
snf_person_head['Google Scholar ID'] = ""
for index, row in snf_person_head.iterrows():
    search_query = scholarly.search_author(row['First Name'] + " " + row['Last Name'])
    gs_record = list(search_query)
    # If multiple records are found, put together a list of GS IDs
    if gs_record:
        snf_person_head.loc[index, 'Google Scholar ID'] = ','.join([e['scholar_id'] for e in gs_record])

# %%
# Checkpoint
with open('snf_person_head_dump', 'wb') as snf_person_head_dump:
  pickle.dump(snf_person_head, snf_person_head_dump)

# %%
snf_person_head.head()
# Out:
#    Last Name First Name  Gender      Institute Name Institute Place  \
# 0    a Marca     Davide    male                 NaN             NaN
# 1    a Marca     Andrea    male                 NaN             NaN
# 2  A. Jafari     Golnaz  female  Universität Luzern          Luzern
# 3     Aaberg      Johan    male                 NaN             NaN
# 4     Aahman    Josefin  female                 NaN             NaN
#
#    Person ID SNSF OCRID Projects as responsible Applicant  \
# 0           53856   NaN                               NaN
# 1          132628   NaN                             67368
# 2          747886   NaN                            191432
# 3          575257   NaN                               NaN
# 4          629557   NaN                               NaN
#
#   Projects as Applicant Projects as Partner Projects as Practice Partner  \
# 0                   NaN                 NaN                          NaN
# 1                   NaN                 NaN                          NaN
# 2                   NaN                 NaN                          NaN
# 3                   NaN                 NaN                          NaN
# 4                   NaN                 NaN                          NaN
#
#   Projects as Employee Projects as Contact Person Google Scholar ID
# 0                36549                        NaN      7ThYw2IAAAAJ
# 1                  NaN                        NaN
# 2                  NaN                        NaN
# 3               119868                        NaN      YUBv7p8AAAAJ
# 4               141014                        NaN

# %% [markdown]
# ## Handle ambiguous identities

# %%
# Find authors with multiple retrieved GS IDs
is_amb = [len(e.split(',')) > 1 for e in snf_person_head['Google Scholar ID']]

# Count ambiguous records
sum(is_amb)
# Out:
# 3

# %%
# Show the ambiguous records
snf_person_head[is_amb]
# Out:
#    Last Name First Name  Gender  \
# 25   Abankwa     Daniel    male
# 32     Abate    Antonio    male
# 34  Abatista     Angela  female
#
#                                        Institute Name Institute Place  \
# 25       Centre for Biotechnology University of Turku           Turku
# 32  Laboratoire de photonique et interfaces EPFL -...        Lausanne
# 34                                                NaN             NaN
#
#     Person ID SNSF                OCRID Projects as responsible Applicant  \
# 25          523490  0000-0003-2769-0745                            111446
# 32          642410                  NaN                               NaN
# 34          774289                  NaN                               NaN
#
#    Projects as Applicant Projects as Partner Projects as Practice Partner  \
# 25                   NaN                 NaN                          NaN
# 32                   NaN                 NaN                          NaN
# 34                   NaN                 NaN                          NaN
#
#    Projects as Employee Projects as Contact Person  \
# 25                  NaN                        NaN
# 32        153952;153990                        NaN
# 34               181083                        NaN
#
#                                     Google Scholar ID
# 25                          XeOgll8AAAAJ,voeFGVMAAAAJ
# 32                          QcgVxfIAAAAJ,K17owBYAAAAJ
# 34  fnPaKuUAAAAJ,sZdJ114AAAAJ,qrYqYO8AAAAJ,2l4x5aA...

# %% [markdown]
# In the case of "Abankwa Daniel", an existing ORCID record can be used to disambiguate the author's identity.

# %%
search_query = scholarly.search_author('Abate Antonio')

# %%
list(search_query)
# Out:
# [{'container_type': 'Author',
#   'filled': set(),
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 2>,
#   'scholar_id': 'QcgVxfIAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=QcgVxfIAAAAJ',
#   'name': 'Antonio Abate',
#   'affiliation': 'Helmholtz-Zentrum Berlin',
#   'email_domain': '@helmholtz-berlin.de',
#   'interests': ['Hybrid solar cells',
#    'Perovskite solar cells',
#    'Perovskites',
#    'Materials',
#    'Supramolecular chemistry'],
#   'citedby': 30316},
#  {'container_type': 'Author',
#   'filled': set(),
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 2>,
#   'scholar_id': 'K17owBYAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=K17owBYAAAAJ',
#   'name': 'Maurizio Giuseppe Abrignani',
#   'affiliation': 'UO di Cardiologia, POS Antonio Abate di Trapani, Italy',
#   'email_domain': '@asptrapani.it',
#   'interests': ['epidemiologia',
#    'fattori di rischio',
#    'ipertensione arteriosa',
#    'dislipidemie',
#    'cardiopatia ischemica'],
#   'citedby': 5543}]

# %% [markdown]
# In this case, verifying that the author name matches a name, and not an affiliation, will be sufficient to disambiguate the identity.

# %%
search_query = scholarly.search_author('Angela Abatista')

# %%
list(search_query)
# Out:
# [{'container_type': 'Author',
#   'filled': set(),
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 2>,
#   'scholar_id': 'fnPaKuUAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=fnPaKuUAAAAJ',
#   'name': 'Ângela Giovana Batista',
#   'affiliation': 'University of Santa Maria - UFSM',
#   'email_domain': '@ufsm.br',
#   'interests': ['bioactive compounds',
#    'compostos bioativos',
#    'polyphenols',
#    'obesity'],
#   'citedby': 1130},
#  {'container_type': 'Author',
#   'filled': set(),
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 2>,
#   'scholar_id': 'sZdJ114AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=sZdJ114AAAAJ',
#   'name': 'Miguel Angel Herrera Batista',
#   'affiliation': 'Universidad Autónoma Metropolitana',
#   'email_domain': '@azc.uam.mx',
#   'interests': ['Educacion',
#    'Diseño',
#    'e-learning',
#    'aprendizaje virtual',
#    'tecnología y educación'],
#   'citedby': 575},
#  {'container_type': 'Author',
#   'filled': set(),
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 2>,
#   'scholar_id': 'qrYqYO8AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=qrYqYO8AAAAJ',
#   'name': 'Angel Antonio Ravelo Batista',
#   'affiliation': 'Profesor de la Universidad de Oriente',
#   'email_domain': '',
#   'interests': ['móviles', 'realidad aumentada', 'IoT', 'Dómotica'],
#   'citedby': 71},
#  {'container_type': 'Author',
#   'filled': set(),
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 2>,
#   'scholar_id': '2l4x5aAAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=2l4x5aAAAAAJ',
#   'name': "Ev'Angela Batista Rodrigues de Barros",
#   'affiliation': 'Professora de Letras PUC Minas',
#   'email_domain': '',
#   'interests': ['letras. linguística. educação. formação …'],
#   'citedby': 5}]

# %% [markdown]
# In this case, comparing the names using a metric like "edit distance" would help in disambiguate the author's identity.
#
# Alternatively, matching existing records with information on GoogleScholar can help. This could include:
#  - Institution names
#  - Bibliography records from P3_PublicationExport.csv
#  - Keywords extracted from P3_PublicationExport.csv and P3_GrantExport.csv

# %%
# Load the SNF publications table
fp = os.path.join(datadir, 'snf', 'P3_PublicationExport.csv')
print(os.path.basename(fp))
snf[os.path.basename(fp)] = pd.read_csv(fp, sep = ";")
# Out:
# P3_PublicationExport.csv

# %%
snf['P3_PublicationExport.csv'].head(5)
# Out:
#                       Publication ID SNSF  Project Number Peer Review Status  \
# 0  {3001D662-AD1B-43DA-8BA2-5ADC25C9C347}            1094      Peer-reviewed
# 1  {3F5669B1-C09F-4486-87FF-21A561C15B8A}           20108      Peer-reviewed
# 2  {12293018-B2F8-4320-A5C8-24C21A2AB7D3}           20108      Peer-reviewed
# 3  {DD1E2D93-7B51-4B32-8062-2AF42F5E4E94}           25095      Peer-reviewed
# 4  {C4B57BD5-668D-47A6-92DA-8CE1962D87DE}           25095      Peer-reviewed
#
#                 Type of Publication  \
# 0              Book (peer-reviewed)
# 1  Original article (peer-reviewed)
# 2  Original article (peer-reviewed)
# 3  Original article (peer-reviewed)
# 4  Original article (peer-reviewed)
#
#                                 Title of Publication  \
# 0                              Platos Idee des Guten
# 1  MICROSTRUCTURE, LATTICE-PARAMETERS, AND SUPERC...
# 2  NEUTRON-POWDER-DIFFRACTION STUDY OF NUCLEAR AN...
# 3  NEUTRON AND SYNCHROTRON X-RAY POWDER-DIFFRACTI...
# 4  HEXAMAGNESIUM DICOBALT UNDECADEUTERIDE {Mg$_6$...
#
#                                              Authors     Status  \
# 0                                      Ferber Rafael  Published
# 1  Xu Y. W.,  Suenaga M.,  Tafto J.,  Sabatini R....  Published
# 2  Zolliker P.,  Cox D. E.,  Tranquada J. M.,  Sh...  Published
# 3  Zolliker P.,  Cox D. E.,  Parise J. B.,  McCar...  Published
# 4  Cerny R.,  Bonhomme F.,  Yvon K.,  Fischer P.,...  Published
#
#    Publication Year               ISBN  \
# 0            2015.0  978-3-89665-666-7
# 1            1989.0                NaN
# 2            1988.0                NaN
# 3            1990.0                NaN
# 4            1992.0                NaN
#
#                                                  DOI  ...  \
# 0                                                NaN  ...
# 1  10.1103/PhysRevB.39.6667                      ...  ...
# 2  10.1103/PhysRevB.38.6575                      ...  ...
# 3  10.1103/PhysRevB.42.6332                      ...  ...
# 4  10.1016/0925-8388(92)90537-j                  ...  ...
#
#                        Publisher  Editors                    Journal Title  \
# 0  Academia Verlag ,St. Augustin      NaN                              NaN
# 1                            NaN      NaN                Physical Review B
# 2                            NaN      NaN                Physical Review B
# 3                            NaN      NaN                Physical Review B
# 4                            NaN      NaN  Journal of Alloys and Compounds
#
#   Volume Issue / Number Page from Page to                 Proceeding Title  \
# 0    NaN            NaN       NaN     NaN                              NaN
# 1     39             10      6667    6680                Physical Review B
# 2     38             10      6575    6582                Physical Review B
# 3     42             10      6332    6341                Physical Review B
# 4    187              1       233     241  Journal of Alloys and Compounds
#
#   Proceeding Place                                           Abstract
# 0              NaN  At the centre of the monograph (1984  first ed...
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3              NaN                                                NaN
# 4              NaN                                                NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# The "DOI" records can be used to match authors bibliography in GoogleScholar.

# %%
# Load the SNF grants table
fp = os.path.join(datadir, 'snf', 'P3_GrantExport.csv')
print(os.path.basename(fp))
snf[os.path.basename(fp)] = pd.read_csv(fp, sep = ";")
# Out:
# P3_GrantExport.csv

# %%
snf['P3_GrantExport.csv'].head(5)
# Out:
#    Project Number Project Number String  \
# 0               1           1000-000001
# 1               4           1000-000004
# 2               5           1000-000005
# 3               6           1000-000006
# 4               7           1000-000007
#
#                                        Project Title Project Title English  \
# 0  Schlussband (Bd. VI) der Jacob Burckhardt-Biog...                   NaN
# 1  Batterie de tests à l'usage des enseignants po...                   NaN
# 2  Kritische Erstausgabe der 'Evidentiae contra D...                   NaN
# 3  Katalog der datierten Handschriften in der Sch...                   NaN
# 4  Wissenschaftliche Mitarbeit am Thesaurus Lingu...                   NaN
#
#                                Responsible Applicant  \
# 0                                       Kaegi Werner
# 1                                 Massarenti Léonard
# 2  Kommission für das Corpus philosophorum medii ...
# 3                                     Burckhardt Max
# 4                       Schweiz. Thesauruskommission
#
#              Funding Instrument Funding Instrument Hierarchy  \
# 0  Project funding (Div. I-III)              Project funding
# 1  Project funding (Div. I-III)              Project funding
# 2  Project funding (Div. I-III)              Project funding
# 3  Project funding (Div. I-III)              Project funding
# 4  Project funding (Div. I-III)              Project funding
#
#                                          Institution Institution Country  \
# 0                                                NaN                 NaN
# 1                         FPSE  Université de Genève         Switzerland
# 2  Kommission für das Corpus philosophorum medii ...         Switzerland
# 3  Abteilung Handschriften und Alte Drucke Univer...         Switzerland
# 4                       Schweiz. Thesauruskommission         Switzerland
#
#                                           University  Discipline Number  \
# 0                                  Unassignable - NA              10302
# 1                          University of Geneva - GE              10104
# 2  Non-profit organisations (libraries, museums, ...              10101
# 3                           University of Basel - BS              10302
# 4  Non-profit organisations (libraries, museums, ...              10303
#
#                                      Discipline Name  \
# 0                                      Swiss history
# 1  Education and learning sciences, subject-speci...
# 2                                         Philosophy
# 3                                      Swiss history
# 4              Ancient history and Classical studies
#
#                            Discipline Name Hierarchy All disciplines  \
# 0  Humanities and Social Sciences;Theology & reli...           10302
# 1  Humanities and Social Sciences;Psychology, edu...           10104
# 2  Humanities and Social Sciences;Linguistics and...           10101
# 3  Humanities and Social Sciences;Theology & reli...           10302
# 4  Humanities and Social Sciences;Theology & reli...           10303
#
#    Start Date    End Date Approved Amount Keywords
# 0  01.10.1975  30.09.1976         11619.0      NaN
# 1  01.10.1975  30.09.1976         41022.0      NaN
# 2  01.03.1976  28.02.1985         79732.0      NaN
# 3  01.10.1975  30.09.1976         52627.0      NaN
# 4  01.01.1976  30.04.1978        120042.0      NaN

# %% [markdown]
# The "Discipline Name Hierarchy" records can be used to extract keywords matching authors interests in GoogleScholar
